# %% [markdown]
# # Modelagem

# %% [markdown]
# ## Preparo dos dados para modelagem

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.impute import SimpleImputer
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (
    classification_report, 
    confusion_matrix, 
    roc_auc_score, 
    accuracy_score, 
    precision_score, 
    recall_score, 
    f1_score, 
    ConfusionMatrixDisplay
)

from sklearn.linear_model import LogisticRegression
from xgboost import XGBClassifier
from sklearn.svm import SVC
from sklearn.ensemble import AdaBoostClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.linear_model import Lasso
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
data_dir = r"C:\Users\biapr\Desktop\SME0880"

# %% [markdown]
# ### Leitura dos dados criados no arquivo 2

# %%
df = pd.read_csv('patient_correlations_with_classification.csv')
df.head(2)
# Out:
#    level_0  level_1  ('vmPFC', 'aPFC')  ('vmPFC', 'aPFC').1  \
# 0    51461        0           0.175695             0.072106
# 1    51463        0          -0.368830            -0.119439
#
#    ('vmPFC', 'mPFC')  ('vmPFC', 'aPFC').2  ('vmPFC', 'vmPFC')  \
# 0           0.081816             0.206274            0.102997
# 1           0.339539            -0.025849            0.308926
#
#    ('vmPFC', 'vmPFC').1  ('vmPFC', 'aPFC').3  ('vmPFC', 'vent aPFC')  ...  \
# 0              0.319958             0.161952                0.364796  ...
# 1              0.068077            -0.026906               -0.036931  ...
#
#    ('post occipital', 'post occipital').19  \
# 0                                 0.335922
# 1                                -0.367171
#
#    ('post occipital', 'post occipital').20  \
# 0                                 0.215270
# 1                                -0.077061
#
#    ('post occipital', 'post occipital').21  \
# 0                                 0.087338
# 1                                -0.358534
#
#    ('post occipital', 'post occipital').22  \
# 0                                 0.045692
# 1                                -0.281108
#
#    ('post occipital', 'post occipital').23  \
# 0                                 0.052163
# 1                                 0.051835
#
#    ('post occipital', 'post occipital').24  \
# 0                                -0.220931
# 1                                -0.300570
#
#    ('post occipital', 'post occipital').25  \
# 0                                 0.311907
# 1                                 0.382619
#
#    ('post occipital', 'post occipital').26  \
# 0                                 0.164347
# 1                                 0.472854
#
#    ('post occipital', 'post occipital').27  diag
# 0                                 0.276658     1
# 1                                -0.066249     1
#
# [2 rows x 12723 columns]

# %%
df.shape
# Out:
# (871, 12723)

# %%
linhas_nan = df.isna().any(axis=1).sum()
"{:.2f}%".format((linhas_nan/len(df))*100,"%")
# Out:
# '5.28%'

# %% [markdown]
# ### Tratamentos iniciais

# %%
df_pacientes = df['level_0']
df_pacientes.head()
# Out:
# 0    51461
# 1    51463
# 2    51464
# 3    51465
# 4    51473
# Name: level_0, dtype: int64

# %%
df = df.drop(['level_0'],axis=1)
df = df.drop(['level_1'],axis=1)
df.head()
# Out:
#    ('vmPFC', 'aPFC')  ('vmPFC', 'aPFC').1  ('vmPFC', 'mPFC')  \
# 0           0.175695             0.072106           0.081816
# 1          -0.368830            -0.119439           0.339539
# 2                NaN                  NaN                NaN
# 3                NaN                  NaN                NaN
# 4          -0.119987             0.080547           0.006978
#
#    ('vmPFC', 'aPFC').2  ('vmPFC', 'vmPFC')  ('vmPFC', 'vmPFC').1  \
# 0             0.206274            0.102997              0.319958
# 1            -0.025849            0.308926              0.068077
# 2                  NaN                 NaN                   NaN
# 3                  NaN                 NaN                   NaN
# 4            -0.287386            0.468913              0.087592
#
#    ('vmPFC', 'aPFC').3  ('vmPFC', 'vent aPFC')  ('vmPFC', 'vent aPFC').1  \
# 0             0.161952                0.364796                  0.175969
# 1            -0.026906               -0.036931                 -0.197185
# 2                  NaN                     NaN                       NaN
# 3                  NaN                     NaN                       NaN
# 4            -0.009376               -0.149551                  0.309103
#
#    ('vmPFC', 'vmPFC').2  ...  ('post occipital', 'post occipital').19  \
# 0             -0.167000  ...                                 0.335922
# 1              0.305320  ...                                -0.367171
# 2                   NaN  ...                                 0.397052
# 3                   NaN  ...                                 0.229935
# 4              0.473186  ...                                 0.268082
#
#    ('post occipital', 'post occipital').20  \
# 0                                 0.215270
# 1                                -0.077061
# 2                                 0.657301
# 3                                 0.421588
# 4                                 0.085097
#
#    ('post occipital', 'post occipital').21  \
# 0                                 0.087338
# 1                                -0.358534
# 2                                 0.333119
# 3                                 0.258974
# 4                                 0.106637
#
#    ('post occipital', 'post occipital').22  \
# 0                                 0.045692
# 1                                -0.281108
# 2                                 0.306018
# 3                                 0.409642
# 4                                 0.439804
#
#    ('post occipital', 'post occipital').23  \
# 0                                 0.052163
# 1                                 0.051835
# 2                                 0.408782
# 3                                 0.730639
# 4                                 0.272471
#
#    ('post occipital', 'post occipital').24  \
# 0                                -0.220931
# 1                                -0.300570
# 2                                 0.191740
# 3                                 0.417771
# 4                                 0.154591
#
#    ('post occipital', 'post occipital').25  \
# 0                                 0.311907
# 1                                 0.382619
# 2                                 0.361156
# 3                                 0.488363
# 4                                 0.487218
#
#    ('post occipital', 'post occipital').26  \
# 0                                 0.164347
# 1                                 0.472854
# 2                                 0.372331
# 3                                -0.048931
# 4                                 0.285554
#
#    ('post occipital', 'post occipital').27  diag
# 0                                 0.276658     1
# 1                                -0.066249     1
# 2                                 0.370931     1
# 3                                 0.272513     1
# 4                                 0.316727     1
#
# [5 rows x 12721 columns]

# %%
df['diag'] = df['diag'].replace({1: 1, 2: 0})

# %%
df['diag']
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 866    1
# 867    1
# 868    1
# 869    1
# 870    1
# Name: diag, Length: 871, dtype: int64

# %%
# Remocao de linhas duplicadas, caso existam
df = df.drop_duplicates()
df.shape
# Out:
# (871, 12721)

# %%
X = df.drop(columns=['diag'])
y = df['diag']

# %%
y[:10]
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# 5    0
# 6    0
# 7    0
# 8    0
# 9    0
# Name: diag, dtype: int64

# %%
# Substituicao dos valores ausentes pela mediana
imputer = SimpleImputer(missing_values=np.nan, strategy='median')
df_imputado = imputer.fit_transform(X)
X = pd.DataFrame(df_imputado, columns=X.columns)

# %%
X.head()
# Out:
#    ('vmPFC', 'aPFC')  ('vmPFC', 'aPFC').1  ('vmPFC', 'mPFC')  \
# 0           0.175695             0.072106           0.081816
# 1          -0.368830            -0.119439           0.339539
# 2           0.073751             0.036094           0.224807
# 3           0.073751             0.036094           0.224807
# 4          -0.119987             0.080547           0.006978
#
#    ('vmPFC', 'aPFC').2  ('vmPFC', 'vmPFC')  ('vmPFC', 'vmPFC').1  \
# 0             0.206274            0.102997              0.319958
# 1            -0.025849            0.308926              0.068077
# 2             0.055795            0.277327              0.344667
# 3             0.055795            0.277327              0.344667
# 4            -0.287386            0.468913              0.087592
#
#    ('vmPFC', 'aPFC').3  ('vmPFC', 'vent aPFC')  ('vmPFC', 'vent aPFC').1  \
# 0             0.161952                0.364796                  0.175969
# 1            -0.026906               -0.036931                 -0.197185
# 2            -0.013900                0.015973                 -0.027559
# 3            -0.013900                0.015973                 -0.027559
# 4            -0.009376               -0.149551                  0.309103
#
#    ('vmPFC', 'vmPFC').2  ...  ('post occipital', 'post occipital').18  \
# 0             -0.167000  ...                                 0.269976
# 1              0.305320  ...                                 0.526180
# 2              0.162245  ...                                 0.309867
# 3              0.162245  ...                                 0.327539
# 4              0.473186  ...                                 0.346862
#
#    ('post occipital', 'post occipital').19  \
# 0                                 0.335922
# 1                                -0.367171
# 2                                 0.397052
# 3                                 0.229935
# 4                                 0.268082
#
#    ('post occipital', 'post occipital').20  \
# 0                                 0.215270
# 1                                -0.077061
# 2                                 0.657301
# 3                                 0.421588
# 4                                 0.085097
#
#    ('post occipital', 'post occipital').21  \
# 0                                 0.087338
# 1                                -0.358534
# 2                                 0.333119
# 3                                 0.258974
# 4                                 0.106637
#
#    ('post occipital', 'post occipital').22  \
# 0                                 0.045692
# 1                                -0.281108
# 2                                 0.306018
# 3                                 0.409642
# 4                                 0.439804
#
#    ('post occipital', 'post occipital').23  \
# 0                                 0.052163
# 1                                 0.051835
# 2                                 0.408782
# 3                                 0.730639
# 4                                 0.272471
#
#    ('post occipital', 'post occipital').24  \
# 0                                -0.220931
# 1                                -0.300570
# 2                                 0.191740
# 3                                 0.417771
# 4                                 0.154591
#
#    ('post occipital', 'post occipital').25  \
# 0                                 0.311907
# 1                                 0.382619
# 2                                 0.361156
# 3                                 0.488363
# 4                                 0.487218
#
#    ('post occipital', 'post occipital').26  \
# 0                                 0.164347
# 1                                 0.472854
# 2                                 0.372331
# 3                                -0.048931
# 4                                 0.285554
#
#    ('post occipital', 'post occipital').27
# 0                                 0.276658
# 1                                -0.066249
# 2                                 0.370931
# 3                                 0.272513
# 4                                 0.316727
#
# [5 rows x 12720 columns]

# %%
# Normalizacao dos dados
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
X_norm = pd.DataFrame(X_scaled, columns=X.columns)
X_norm.head()
# Out:
#    ('vmPFC', 'aPFC')  ('vmPFC', 'aPFC').1  ('vmPFC', 'mPFC')  \
# 0           0.470575             0.149894          -0.643545
# 1          -1.799519            -0.754264           0.519128
# 2           0.045574            -0.020095           0.001534
# 3           0.045574            -0.020095           0.001534
# 4          -0.762108             0.189737          -0.981164
#
#    ('vmPFC', 'aPFC').2  ('vmPFC', 'vmPFC')  ('vmPFC', 'vmPFC').1  \
# 0             0.754705           -0.786495             -0.061230
# 1            -0.345039            0.185751             -1.241045
# 2             0.041771            0.036565              0.054507
# 3             0.041771            0.036565              0.054507
# 4            -1.584139            0.941097             -1.149634
#
#    ('vmPFC', 'aPFC').3  ('vmPFC', 'vent aPFC')  ('vmPFC', 'vent aPFC').1  \
# 0             0.787668                1.595409                  0.943766
# 1            -0.059000               -0.236849                 -0.844390
# 2            -0.000692                0.004444                 -0.031542
# 3            -0.000692                0.004444                 -0.031542
# 4             0.019587               -0.750502                  1.581746
#
#    ('vmPFC', 'vmPFC').2  ...  ('post occipital', 'post occipital').18  \
# 0             -1.658062  ...                                -0.654597
# 1              0.735973  ...                                 0.559859
# 2              0.010773  ...                                -0.465507
# 3              0.010773  ...                                -0.381737
# 4              1.586828  ...                                -0.290143
#
#    ('post occipital', 'post occipital').19  \
# 0                                 0.882215
# 1                                -2.557647
# 2                                 1.181291
# 3                                 0.363674
# 4                                 0.550312
#
#    ('post occipital', 'post occipital').20  \
# 0                                -0.489538
# 1                                -1.810078
# 2                                 1.507237
# 3                                 0.442457
# 4                                -1.077564
#
#    ('post occipital', 'post occipital').21  \
# 0                                -0.300337
# 1                                -2.408090
# 2                                 0.861535
# 3                                 0.511036
# 4                                -0.209103
#
#    ('post occipital', 'post occipital').22  \
# 0                                -0.821291
# 1                                -2.394683
# 2                                 0.432058
# 3                                 0.930958
# 4                                 1.076174
#
#    ('post occipital', 'post occipital').23  \
# 0                                -1.293883
# 1                                -1.295400
# 2                                 0.356775
# 3                                 1.846531
# 4                                -0.274160
#
#    ('post occipital', 'post occipital').24  \
# 0                                -2.126504
# 1                                -2.499467
# 2                                -0.193894
# 3                                 0.864646
# 4                                -0.367870
#
#    ('post occipital', 'post occipital').25  \
# 0                                 0.331586
# 1                                 0.648710
# 2                                 0.552456
# 3                                 1.122943
# 4                                 1.117807
#
#    ('post occipital', 'post occipital').26  \
# 0                                -0.781388
# 1                                 0.540986
# 2                                 0.110106
# 3                                -1.695575
# 4                                -0.261850
#
#    ('post occipital', 'post occipital').27
# 0                                 0.631360
# 1                                -0.907424
# 2                                 1.054406
# 3                                 0.612758
# 4                                 0.811165
#
# [5 rows x 12720 columns]

# %%
X_norm.shape
# Out:
# (871, 12720)

# %%
X.shape
# Out:
# (871, 12720)

# %% [markdown]
# ## Aplicação dos modelos

# %%
# Validacao com k-folds estratificado
n_splits = 5
skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=42)

# %% [markdown]
# ### Regressão Logística

# %%
# Regressão logística com X
logistic_model = LogisticRegression(max_iter=1000)

y_real = []
y_pred = []

# Validacao cruzada
for train_index, test_index in skf.split(X, y):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]
    
    logistic_model.fit(X_train, y_train)
    y_pred_fold = logistic_model.predict(X_test)
    
    y_real.extend(y_test)
    y_pred.extend(y_pred_fold)

# Avaliacao do modelo
print("Resultados para Regressão Logística:")
lm = classification_report(y_real, y_pred)
print(lm)

# Matriz de confusão
cm = confusion_matrix(y_real, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=[0, 1])
disp.plot(cmap=plt.cm.Blues)
plt.title('Matriz de confusão para regressão logística:')
plt.show()
# Out:
# Resultados para Regressão Logística:
#               precision    recall  f1-score   support
#
#            0       0.65      0.69      0.67       468
#            1       0.61      0.57      0.59       403
#
#     accuracy                           0.63       871
#    macro avg       0.63      0.63      0.63       871
# weighted avg       0.63      0.63      0.63       871

# %%
# Regressão logística com X normalizado
logistic_model_norm = LogisticRegression(max_iter=1000)

y_real = []
y_pred = []

# Validacao cruzada
for train_index, test_index in skf.split(X_norm, y):
    X_train, X_test = X_norm.iloc[train_index], X_norm.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]
    
    logistic_model.fit(X_train, y_train)
    y_pred_fold = logistic_model.predict(X_test)
    
    y_real.extend(y_test)
    y_pred.extend(y_pred_fold)

# Avaliacao do modelo
print("Resultados para Regressão Logística com os dados normalizados")
print(classification_report(y_real, y_pred))

# Matriz de confusão
cm = confusion_matrix(y_real, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=[0, 1])
disp.plot(cmap=plt.cm.Blues)
plt.title('Matriz de confusão para Regressão Logística com os dados normalizados')
plt.show()
# Out:
# Resultados para Regressão Logística com os dados normalizados
#               precision    recall  f1-score   support
#
#            0       0.66      0.69      0.67       468
#            1       0.62      0.58      0.60       403
#
#     accuracy                           0.64       871
#    macro avg       0.64      0.63      0.63       871
# weighted avg       0.64      0.64      0.64       871

# %% [markdown]
# ### XGBoost: XGBClassifier

# %%
# XGBoost com X
xgb_model = XGBClassifier()

y_real = []
y_pred = []

# Validacao cruzada
for train_index, test_index in skf.split(X, y):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]
    
    xgb_model.fit(X_train, y_train)
    y_pred_fold = xgb_model.predict(X_test)
    
    y_real.extend(y_test)
    y_pred.extend(y_pred_fold)

# Avaliacao do modelo
print("Resultados para XGBoost")
print(classification_report(y_real, y_pred))

# Matriz de confusão
cm = confusion_matrix(y_real, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=[0, 1])
disp.plot(cmap=plt.cm.Blues)
plt.title('Matriz de confusão para XGBoost')
plt.show()
# Out:
# Resultados para XGBoost
#               precision    recall  f1-score   support
#
#            0       0.62      0.69      0.65       468
#            1       0.58      0.50      0.54       403
#
#     accuracy                           0.60       871
#    macro avg       0.60      0.59      0.59       871
# weighted avg       0.60      0.60      0.60       871

# %%
# XGBoost com X normalizado
xgb_model = XGBClassifier()

y_real = []
y_pred = []

# Validacao cruzada
for train_index, test_index in skf.split(X_norm, y):
    X_train, X_test = X_norm.iloc[train_index], X_norm.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]
    
    xgb_model.fit(X_train, y_train)
    y_pred_fold = xgb_model.predict(X_test)
    
    y_real.extend(y_test)
    y_pred.extend(y_pred_fold)

# Avaliacao do modelo
print("Resultados para XGBoost com dados normalizados")
print(classification_report(y_real, y_pred))

# Matriz de confusão
cm = confusion_matrix(y_real, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=[0, 1])
disp.plot(cmap=plt.cm.Blues)
plt.title('Matriz de confusão para XGBoost com dados normalizados')
plt.show()
# Out:
# Resultados para XGBoost com dados normalizados
#               precision    recall  f1-score   support
#
#            0       0.62      0.69      0.65       468
#            1       0.58      0.50      0.54       403
#
#     accuracy                           0.60       871
#    macro avg       0.60      0.59      0.59       871
# weighted avg       0.60      0.60      0.60       871

# %% [markdown]
# ### AdaBoost: AdaBoostClassifier

# %%
# AdaBoost com X
ada_model = AdaBoostClassifier()

y_real = []
y_pred = []

# Validacao cruzada
for train_index, test_index in skf.split(X, y):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]
    
    ada_model.fit(X_train, y_train)
    y_pred_fold = ada_model.predict(X_test)
    
    y_real.extend(y_test)
    y_pred.extend(y_pred_fold)

# Avaliacao do modelo
print("Resultados para AdaBoost")
print(classification_report(y_real, y_pred))

# Matriz de confusão
cm = confusion_matrix(y_real, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=[0, 1])
disp.plot(cmap=plt.cm.Blues)
plt.title('Matriz de confusão para AdaBoost')
plt.show()
# Out:
# Resultados para AdaBoost
#               precision    recall  f1-score   support
#
#            0       0.57      0.58      0.58       468
#            1       0.51      0.50      0.50       403
#
#     accuracy                           0.54       871
#    macro avg       0.54      0.54      0.54       871
# weighted avg       0.54      0.54      0.54       871

# %%
# AdaBoost com X
ada_model = AdaBoostClassifier()

y_real = []
y_pred = []

# Validacao cruzada
for train_index, test_index in skf.split(X_norm, y):
    X_train, X_test = X_norm.iloc[train_index], X_norm.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]
    
    ada_model.fit(X_train, y_train)
    y_pred_fold = ada_model.predict(X_test)
    
    y_real.extend(y_test)
    y_pred.extend(y_pred_fold)

# Avaliacao do modelo
print("Resultados para AdaBoost com dados normalizados")
print(classification_report(y_real, y_pred))

# Matriz de confusão
cm = confusion_matrix(y_real, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=[0, 1])
disp.plot(cmap=plt.cm.Blues)
plt.title('Matriz de confusão para AdaBoost com dados normalizados')
plt.show()
# Out:
# Resultados para AdaBoost com dados normalizados
#               precision    recall  f1-score   support
#
#            0       0.57      0.58      0.58       468
#            1       0.51      0.50      0.50       403
#
#     accuracy                           0.54       871
#    macro avg       0.54      0.54      0.54       871
# weighted avg       0.54      0.54      0.54       871

# %% [markdown]
# ### Naive Bayes: GaussianNB

# %%
# Naive Bayes com X
nb_model = GaussianNB()

y_real = []
y_pred = []

# Validacao cruzada
for train_index, test_index in skf.split(X, y):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]
    
    nb_model.fit(X_train, y_train)
    y_pred_fold = nb_model.predict(X_test)
    
    y_real.extend(y_test)
    y_pred.extend(y_pred_fold)

# Avaliacao do modelo
print("Resultados para Naive Bayes")
print(classification_report(y_real, y_pred))

# Matriz de confusão
cm = confusion_matrix(y_real, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=[0, 1])
disp.plot(cmap=plt.cm.Blues)
plt.title('Matriz de confusão para Naive Bayes')
plt.show()
# Out:
# Resultados para Naive Bayes
#               precision    recall  f1-score   support
#
#            0       0.66      0.56      0.61       468
#            1       0.57      0.67      0.61       403
#
#     accuracy                           0.61       871
#    macro avg       0.62      0.61      0.61       871
# weighted avg       0.62      0.61      0.61       871

# %% [markdown]
# ### KNN: KNeighborsClassifier

# %%
# KNN com X
knn_model = KNeighborsClassifier()

y_real = []
y_pred = []

# Validacao cruzada
for train_index, test_index in skf.split(X, y):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]
    
    knn_model.fit(X_train, y_train)
    y_pred_fold = knn_model.predict(X_test)
    
    y_real.extend(y_test)
    y_pred.extend(y_pred_fold)

# Avaliacao do modelo
print("Resultados para KNN")
print(classification_report(y_real, y_pred))

# Matriz de confusão
cm = confusion_matrix(y_real, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=[0, 1])
disp.plot(cmap=plt.cm.Blues)
plt.title('Matriz de confusão para KNN')
plt.show()
# Out:
# Resultados para KNN
#               precision    recall  f1-score   support
#
#            0       0.58      0.66      0.62       468
#            1       0.54      0.45      0.49       403
#
#     accuracy                           0.56       871
#    macro avg       0.56      0.56      0.56       871
# weighted avg       0.56      0.56      0.56       871

# %% [markdown]
# ### Multilayer Perceptron (MLP): MLPClassifier

# %%
# Multilayer Perceptron (MLP) com X
mlp_model = MLPClassifier(max_iter=1000)

y_real = []
y_pred = []

# Validacao cruzada
for train_index, test_index in skf.split(X, y):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]
    
    mlp_model.fit(X_train, y_train)
    y_pred_fold = mlp_model.predict(X_test)
    
    y_real.extend(y_test)
    y_pred.extend(y_pred_fold)

# Avaliacao do modelo
print("Resultados para Multilayer Perceptron (MLP)")
print(classification_report(y_real, y_pred))

# Matriz de confusão
cm = confusion_matrix(y_real, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=[0, 1])
disp.plot(cmap=plt.cm.Blues)
plt.title('Matriz de confusão para Multilayer Perceptron (MLP)')
plt.show()
# Out:
# Resultados para Multilayer Perceptron (MLP)
#               precision    recall  f1-score   support
#
#            0       0.64      0.71      0.68       468
#            1       0.62      0.54      0.58       403
#
#     accuracy                           0.63       871
#    macro avg       0.63      0.63      0.63       871
# weighted avg       0.63      0.63      0.63       871

# %% [markdown]
# ### Random Forest

# %%
# Random Forest com X
rf_model = RandomForestClassifier()

y_real = []
y_pred = []

# Validacao cruzada
for train_index, test_index in skf.split(X, y):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]
    
    rf_model.fit(X_train, y_train)
    y_pred_fold = rf_model.predict(X_test)
    
    y_real.extend(y_test)
    y_pred.extend(y_pred_fold)

# Avaliacao do modelo
print("Resultados para Random Forest")
print(classification_report(y_real, y_pred))

# Matriz de confusão
cm = confusion_matrix(y_real, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=[0, 1])
disp.plot(cmap=plt.cm.Blues)
plt.title('Matriz de confusão para Random Forest')
plt.show()
# Out:
# Resultados para Random Forest
#               precision    recall  f1-score   support
#
#            0       0.58      0.76      0.66       468
#            1       0.57      0.36      0.44       403
#
#     accuracy                           0.58       871
#    macro avg       0.57      0.56      0.55       871
# weighted avg       0.58      0.58      0.56       871

# %% [markdown]
# ### SVM

# %%
# SVM com X
svm_model = SVC()

y_real = []
y_pred = []

# Validacao cruzada
for train_index, test_index in skf.split(X, y):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]
    
    svm_model.fit(X_train, y_train)
    y_pred_fold = svm_model.predict(X_test)
    
    y_real.extend(y_test)
    y_pred.extend(y_pred_fold)

# Avaliacao do modelo
print("Resultados para SVM")
print(classification_report(y_real, y_pred))

# Matriz de confusão
cm = confusion_matrix(y_real, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=[0, 1])
disp.plot(cmap=plt.cm.Blues)
plt.title('Matriz de confusão para SVM')
plt.show()
# Out:
# Resultados para SVM
#               precision    recall  f1-score   support
#
#            0       0.65      0.75      0.70       468
#            1       0.65      0.53      0.58       403
#
#     accuracy                           0.65       871
#    macro avg       0.65      0.64      0.64       871
# weighted avg       0.65      0.65      0.64       871

# %% [markdown]
# ### Decision Tree

# %%
# SVM com X
dt_model = DecisionTreeClassifier()

y_real = []
y_pred = []

# Validacao cruzada
for train_index, test_index in skf.split(X, y):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]
    
    dt_model.fit(X_train, y_train)
    y_pred_fold = dt_model.predict(X_test)
    
    y_real.extend(y_test)
    y_pred.extend(y_pred_fold)

# Avaliacao do modelo
print("Resultados para Árvore de Decisão")
print(classification_report(y_real, y_pred))

# Matriz de confusão
cm = confusion_matrix(y_real, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=[0, 1])
disp.plot(cmap=plt.cm.Blues)
plt.title('Matriz de confusão para Árvore de Decisão')
plt.show()
# Out:
# Resultados para Árvore de Decisão
#               precision    recall  f1-score   support
#
#            0       0.59      0.58      0.58       468
#            1       0.52      0.52      0.52       403
#
#     accuracy                           0.55       871
#    macro avg       0.55      0.55      0.55       871
# weighted avg       0.55      0.55      0.55       871

# %% [markdown]
# ## Comparação dos modelos

# %%
metricas = {
    'Modelos' : ['Regressão Logística' , 'XGBoost' , 'AdaBoost', 'Naive Bayes', 'KNN', 'MPL', 'Random Forest', 'SVM', 'Decision Tree'],
    'Precision': [0.63, 0.60, 0.54, 0.62, 0.56, 0.64, 0.57, 0.65, 0.55],
    'Recall' : [0.63, 0.59, 0.54, 0.61, 0.56, 0.63, 0.56, 0.64, 0.55],
    'F1-Score' : [0.63, 0.59, 0.54, 0.61, 0.56, 0.63, 0.55, 0.64, 0.55],
    'Acuracia ' : [0.63, 0.60, 0.54, 0.61, 0.56, 0.64, 0.58, 0.65, 0.55],
    'Suport' : [871, 871, 871, 871, 871, 871, 871, 871, 871],
    'TP' : [229, 201, 200, 270, 182, 219, 145, 212, 211],
    'TN' : [322, 323, 272, 262, 310, 333, 358, 353, 272],
    'FP' : [146, 145, 196, 206, 158, 135, 110, 115, 196],
    'FN' : [174, 202, 203, 133, 221, 184, 258, 191, 192]
}

tabela = pd.DataFrame(metricas)

tabela.head(10)
# Out:
#                Modelos  Precision  Recall  F1-Score  Acuracia   Suport   TP  \
# 0  Regressão Logística       0.63    0.63      0.63       0.63     871  229
# 1              XGBoost       0.60    0.59      0.59       0.60     871  201
# 2             AdaBoost       0.54    0.54      0.54       0.54     871  200
# 3          Naive Bayes       0.62    0.61      0.61       0.61     871  270
# 4                  KNN       0.56    0.56      0.56       0.56     871  182
# 5                  MPL       0.64    0.63      0.63       0.64     871  219
# 6        Random Forest       0.57    0.56      0.55       0.58     871  145
# 7                  SVM       0.65    0.64      0.64       0.65     871  212
# 8        Decision Tree       0.55    0.55      0.55       0.55     871  211
#
#     TN   FP   FN
# 0  322  146  174
# 1  323  145  202
# 2  272  196  203
# 3  262  206  133
# 4  310  158  221
# 5  333  135  184
# 6  358  110  258
# 7  353  115  191
# 8  272  196  192

# %%
dados_avaliacao = tabela[['Modelos', 'Precision', 'Recall', 'F1-Score', 'Acuracia ']]
dados_contagem = tabela[['Modelos', 'TP', 'TN', 'FP', 'FN']]

# %%
dados_avaliacao_melted = pd.melt(dados_avaliacao, id_vars='Modelos', var_name='Métrica', value_name='Valor')
dados_contagem_melted = pd.melt(dados_contagem, id_vars='Modelos', var_name='Métrica', value_name='Valor')

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(15, 4))

plt.subplot(1, 2, 1)
sns.lineplot(data=dados_avaliacao_melted, x='Métrica', y='Valor', hue='Modelos', marker='o')
plt.title('Avaliação do Modelo')
plt.xlabel('Métrica')
plt.ylabel('Valor')
plt.xticks(rotation=45, ha='right')
plt.legend().remove() 


plt.subplot(1, 2, 2)
sns.lineplot(data=dados_contagem_melted, x='Métrica', y='Valor', hue='Modelos', marker='o')
plt.title('Contagem')
plt.xlabel('Métrica')
plt.ylabel('Valor')
plt.xticks(rotation=45, ha='right')
plt.legend().remove() 


import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

handles, labels = plt.gca().get_legend_handles_labels()
plt.legend(handles, labels, bbox_to_anchor=(1.05, 1), loc='upper left')

plt.tight_layout()
plt.show()
# Out:
# C:\Users\biapr\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\biapr\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\biapr\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\biapr\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# O modelo que obteve as melhores métricas de avaliação foi o SVM, porém, nenhum deles obteve uma performance aceitável.
# Vale destacar que o Naive Bayes teve a menor quantidade de falso-negativo, o que pode ser interessante quando fala-se de dados de diagnóstico.
